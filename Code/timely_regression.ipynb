# %%
import pandas as pd
df_time = pd.read_csv("C:/부동산/CGKim/Data/df_time.csv", index_col="년월")
df_time
# Out:
#         주택담보대출금리    미국달러     일본엔       유로  소비자물가지수  소비자물가지수증감률  KOSPI_종가  \
# 년월
# 200701      6.11   940.9  7.7310  1220.07   76.496         0.2   1360.23
# 200702      6.18   938.3  7.9389  1241.89   77.017         0.7   1417.34
# 200703      6.20   940.3  7.9700  1253.94   77.464         0.6   1452.55
# 200704      6.13   929.4  7.7833  1266.91   77.761         0.4   1542.24
# 200705      6.17   929.9  7.6475  1249.00   77.836         0.1   1700.91
# ...          ...     ...     ...      ...      ...         ...       ...
# 202209      4.79  1434.8  9.9325  1408.83  108.930         0.3   2155.49
# 202210      4.82  1419.3  9.6119  1413.34  109.210         0.3   2293.61
# 202211      4.74  1331.5  9.5954  1374.31  109.100        -0.1   2472.53
# 202212      4.63  1267.3  9.5318  1351.20  109.280         0.2   2236.40
# 202301      4.58  1228.7  9.4222  1332.83  110.100         0.8   2425.08
#
#         KOSDAQ_종가  무담보콜금리  KORIBOR    CD  국고채_1년  국고채_10년        면적당가격
# 년월
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
model = LinearRegression()
X = df_time[['미국달러', '유로', '소비자물가지수',
       'KOSDAQ_종가', '무담보콜금리', 'KORIBOR', '국고채_1년']]
y = df_time[['면적당가격']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
model = LinearRegression().fit(X_train, y_train)

# %%
print("학습용 :", model.score(X_train, y_train))
print("검증용 :", model.score(X_test, y_test))
# Out:
# 학습용 : 0.8768534565853283
# 검증용 : 0.8887014892522833

# %%
미국달러 = 1000
유로 = 1200
소비자물가지수 = 80
KOSDAQ_종가 = 700
무담보콜금리 = 5
KORIBOR = 5
국고채_1년 = 5

timeA = [미국달러, 유로, 소비자물가지수, KOSDAQ_종가, 무담보콜금리, KORIBOR, 국고채_1년]
valueA = model.predict([timeA])
valueA
# Out:
# c:\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[310.22858162]])

# %%
미국달러 = 1100
유로 = 1300
소비자물가지수 = 100
KOSDAQ_종가 = 700
무담보콜금리 = 1.5
KORIBOR = 1.5
국고채_1년 = 1.5

timeB = [미국달러, 유로, 소비자물가지수, KOSDAQ_종가, 무담보콜금리, KORIBOR, 국고채_1년]
valueB = model.predict([timeB])
valueB
# Out:
# c:\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[854.64696092]])

# %%
미국달러 = 1200
유로 = 1300
소비자물가지수 = 110
KOSDAQ_종가 = 700
무담보콜금리 = 3
KORIBOR = 4
국고채_1년 = 3

timeC = [미국달러, 유로, 소비자물가지수, KOSDAQ_종가, 무담보콜금리, KORIBOR, 국고채_1년]
valueC = model.predict([timeC])
valueC
# Out:
# c:\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1366.01210928]])
